# %%
pip install --upgrade trimesh
# Out:
# Requirement already satisfied: trimesh in /Users/andreadi/venv/lib/python3.9/site-packages (3.23.5)
# Collecting trimesh
#   Downloading trimesh-4.6.6-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.20 in /Users/andreadi/venv/lib/python3.9/site-packages (from trimesh) (2.0.2)
# Downloading trimesh-4.6.6-py3-none-any.whl (709 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 12.0 MB/s eta 0:00:00
# Installing collected packages: trimesh
#   Attempting uninstall: trimesh
#     Found existing installation: trimesh 3.23.5
#     Uninstalling trimesh-3.23.5:
#       Successfully uninstalled trimesh-3.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyembree 0.1.12 requires numpy<2.0.0,>=1.22.2, but you have numpy 2.0.2 which is incompatible.
# pyembree 0.1.12 requires trimesh<4.0.0,>=3.10.7, but you have trimesh 4.6.6 which is incompatible.
# Successfully installed trimesh-4.6.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --force-reinstall numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl.metadata (60 kB)
# Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# napari 0.5.4 requires numpy<2,>=1.22.2; python_version < "3.10", but you have numpy 2.0.2 which is incompatible.
# pyembree 0.1.12 requires numpy<2.0.0,>=1.22.2, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib

# %%
pip install "napari[all]"

# %%
pip install napari

# %%
pip install tifffile

# %%
pip install scipy

# %%
pip install scikit-image

# %%
pip install scikit-learn

# %%
pip install --upgrade setuptools wheel

# %%
pip install numba

# %%
pip install orientationpy

# %%
pip install ipywidgets

# %%
pip install opencv-contrib-python-headless

# %%
pip install jupyter_contrib_nbextensions

# %%
pip install ipywidgets

# %%
pip install fast_simplification

# %%
pip install seaborn

# %%
pip install rtree

# %%
pip install cv2

# %%
pip install open3d

# %%
pip install pyvista
